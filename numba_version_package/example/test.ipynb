# %% [markdown]
# # example1

# %%
import LSHlink as LSH
import sklearn
import numpy as np

# %%
X = [[i] for i in [2, 8, 0, 4, 1, 9, 9, 0]]
X = np.array(X)
test2 = LSH.HASH_FUNS(X)
test2.set_parameters(4,10,2,11)
output = test2.fit_data()
output
# Out:
# already create binary table
# the iteration is  1
# the iteration is  2
# the iteration is  3
# [[0, 4, 1.125, 2],
#  [1, 5, 1.125, 2],
#  [9, 6, 1.125, 3],
#  [2, 8, 1.125, 3],
#  [11, 7, 1.125, 4],
#  [12, 3, 2.25, 5],
#  [10, 13, 4.5, 8]]

# %%
test2.plot_dendrogram()

# %% [markdown]
# # example2

# %%
import LSHlink as LSH
import sklearn
import numpy as np

# %%
data = sklearn.datasets.load_iris().data
data = data[:,:]*10 - data.min(axis=0)*10
data = np.array(data, dtype='int')

test = LSH.HASH_FUNS(data)
test.set_parameters(200,10,2,15)
pass
output = test.fit_data()
# Out:
# already create binary table
# the iteration is  1
# the iteration is  2
# the iteration is  3
# the iteration is  4
# the iteration is  5

# %%
test.plot_raw_data()

# %%
test.plot_cluster()

# %%
test.plot_dendrogram()
